# %%
import sys
sys.path.append('src')

from graph_navigator import Navigator

# %%
nav = Navigator('data/nodes.csv', 'data/edges.csv')
print(f"Total nodes: {nav.graph.nVertices()}")
print(f"Total edges: {nav.graph.nEdges()}")
# Out:
# Total nodes: 8
# Total edges: 15

# %%
path_A_to_J = nav.find_route('A', 'H')
print("Path found:", path_A_to_J)
# Out:
# Path found: [0, 5, 3, 7]

# %%
nav.graph.r_edgeWeight('A', 'H')
path_A_to_J_risk = nav.find_route('A', 'H', risk=True)
print("Path found with risk:", path_A_to_J_risk)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 nav.graph.r_edgeWeight('A', 'H')
#       2 path_A_to_J_risk = nav.find_route('A', 'H', risk=True)
#       3 print("Path found with risk:", path_A_to_J_risk)
#
# File ~/Documents/Projects/DSA/DSA_Final_PartB/src/weighted_graph.py:51, in WeightedGraph.r_edgeWeight(self, A, B)
#      50 def r_edgeWeight(self, A, B):
# ---> 51     self.validIndex(A)
#      52     self.validIndex(B)
#      53     return (self._adjMat[A, B] * self.r_adjMat[A, B] if (A, B) in self._adjMat
#      54             else math.inf)
#
# File ~/Documents/Projects/DSA/DSA_Final_PartB/src/weighted_graph.py:22, in WeightedGraph.validIndex(self, n)
#      21 def validIndex(self, n):
# ---> 22     if n < 0 or self.nVertices() <= n:
#      23         raise IndexError
#      24     return True
#
# ...
